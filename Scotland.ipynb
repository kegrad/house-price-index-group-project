# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Average-prices-2022-07.csv")
#df.head()

# %%
df_scotland = df[df['Area_Code'].str.match('S' )]
df_scotland = df_scotland[df_scotland['Region_Name'] != 'Scotland']
#df_scotland.head(50)

# %%
plt.figure(figsize=(16, 8), dpi=300)
df_average_price=df_scotland.pivot(index='Date',columns='Region_Name',values='Average_Price')
##df_average_price[['City of Edinburgh','City of Glasgow', 'Stirling','Orkney Islands']].plot()
#df_average_price.plot()
# adding title to the plot
#plt.title('Average price')
  
# adding labels to the axes, add a legend
#plt.xlabel('Date')
#plt.ylabel('Average Price')
#plt.legend()

# %%
plt.figure(figsize=(16, 8), dpi=300)
df_annual_change=df_scotland.pivot(index='Date',columns='Region_Name',values='Annual_Change')
##df_annual_change[['City of Edinburgh','City of Glasgow', 'Stirling','Orkney Islands']].plot()
#df_annual_change.plot()
# adding title to the plot
#plt.title('')
  
# adding labels to the axes, add a legend
#plt.xlabel('Date')
#plt.ylabel('Annual Change')
#plt.legend()

# %%
plt.figure(figsize=(16, 8), dpi=300)
df_monthly_change=df_scotland.pivot(index='Date',columns='Region_Name',values='Monthly_Change')
#df_monthly_change[['Highland', 'Stirling', 'Orkney Islands' , 'City of Edinburgh']].plot()
#df_monthly_change.plot()
#plt.title('')
  
# adding labels to the axes, add a legend
#plt.xlabel('Date')
#plt.ylabel('Monthly Change')
#plt.legend()

# %% [markdown]
# Urban includs 15 regions: Aberdeen City ,Dundee City, East Dunbartonshire,
# East Renfrewshire, City of Edinburgh, Falkirk, Glasgow City, Inverclyde, Midlothian,
# North Ayrshire, North Lanarkshire, Renfrewshire, South Lanarkshire, West Dunbartonshire, West Lothian

# %%
##Urban1
plt.figure(figsize=(16, 8), dpi=300)
df_annual_change[['Midlothian','City of Edinburgh', 'East Dunbartonshire' , 
                  'East Renfrewshire', 'West Lothian']].plot()

#df_annual_change[['City of Aberdeen', 'City of Dundee', 'East Dunbartonshire' , 'East Renfrewshire', 
#                  'City of Edinburgh', 'Falkirk', 'City of Glasgow', 'Inverclyde', 'Midlothian', 
#                  'North Ayrshire', 'North Lanarkshire', 'Renfrewshire', 'South Lanarkshire', 
#                  'West Dunbartonshire', 'West Lothian']].plot()


plt.title('Urban annual change')
  
# adding labels to the axes, add a legend
plt.xlabel('Date')
plt.ylabel('Annual_Change')
plt.legend()

# %%
##Urban1
plt.figure(figsize=(16, 8), dpi=300)
df_average_price=df_scotland.pivot(index='Date',columns='Region_Name',values='Average_Price')
df_average_price[['Midlothian','City of Edinburgh', 'East Dunbartonshire' , 
                  'East Renfrewshire', 'West Lothian']].plot()
#df_average_price.plot()
plt.title('Urban average price')
# Out:
# Text(0.5, 1.0, 'Urban average price')

# %%
##Urban2
plt.figure(figsize=(16, 8), dpi=300)
df_annual_change[['South Lanarkshire', 'Falkirk', 'City of Glasgow', 'City of Dundee', 'City of Aberdeen']].plot()

plt.title('Urban annual change')
  
# adding labels to the axes, add a legend
plt.xlabel('Date')
plt.ylabel('Annual_Change')
plt.legend()

# %%
##Urban2
plt.figure(figsize=(16, 8), dpi=300)
df_average_price=df_scotland.pivot(index='Date',columns='Region_Name',values='Average_Price')
df_average_price[['South Lanarkshire', 'Falkirk', 'City of Glasgow', 'City of Dundee', 'City of Aberdeen']].plot()
plt.title('Urban average price')
#df_average_price.plot()
# Out:
# Text(0.5, 1.0, 'Urban average price')

# %%
##Urban3
plt.figure(figsize=(16, 8), dpi=300)
df_annual_change[['Inverclyde', 'North Ayrshire', 'North Lanarkshire', 
                  'Renfrewshire', 'West Dunbartonshire']].plot()

plt.title('Urban annual change')
  
# adding labels to the axes, add a legend
plt.xlabel('Date')
plt.ylabel('Annual_Change')
plt.legend()

# %%
##Urban3
plt.figure(figsize=(16, 8), dpi=300)
df_average_price=df_scotland.pivot(index='Date',columns='Region_Name',values='Average_Price')
df_average_price[['Inverclyde', 'North Ayrshire', 'North Lanarkshire', 
                  'Renfrewshire', 'West Dunbartonshire']].plot()
plt.title('Urban average price')
#df_average_price.plot()
# Out:
# Text(0.5, 1.0, 'Urban average price')

# %% [markdown]
# Rural includs 16 regions: Aberdeenshire, Angus, Argyll and Bute, Dumfries and Galloway,
# East Ayrshire, East Lothian, Fife, Highland, Moray, Na h-Eileanan Siar, Orkney Islands,
# Perth and Kinross, Scottish Borders, Shetland Islands, South Ayrshire, Stirling

# %% [markdown]
# Clackmannanshire has been excluded as outlier due to there is a large population living in small towns.

# %%
##Rural1
plt.figure(figsize=(16, 8), dpi=300)
df_annual_change[['Aberdeenshire', 'Perth and Kinross',
                  'East Lothian',  'Stirling', 'Orkney Islands']].plot()

plt.title('Rural annual change')
  
# adding labels to the axes, add a legend
plt.xlabel('Date')
plt.ylabel('Annual_Change')
plt.legend()

# %%
##Rural1
plt.figure(figsize=(16, 8), dpi=300)
df_average_price=df_scotland.pivot(index='Date',columns='Region_Name',values='Average_Price')
df_average_price[['Aberdeenshire', 'Perth and Kinross',
                  'East Lothian',  'Stirling', 'Orkney Islands']].plot()
plt.title('Rural average price')
#df_average_price.plot()
# Out:
# Text(0.5, 1.0, 'Rural average price')

# %%
##Rural2
plt.figure(figsize=(16, 8), dpi=300)
df_annual_change[['Argyll and Bute', 'Highland','Scottish Borders',
                  'Moray', 'Shetland Islands']].plot()

plt.title('Rural annual change')
  
# adding labels to the axes, add a legend
plt.xlabel('Date')
plt.ylabel('Annual_Change')
plt.legend()

# %%
##Rural2
plt.figure(figsize=(16, 8), dpi=300)
df_average_price=df_scotland.pivot(index='Date',columns='Region_Name',values='Average_Price')
df_average_price[['Argyll and Bute', 'Highland','Scottish Borders',
                  'Moray', 'Shetland Islands']].plot()
plt.title('Rural average price')
#df_average_price.plot()
# Out:
# Text(0.5, 1.0, 'Rural average price')

# %%
##Rural3
plt.figure(figsize=(16, 8), dpi=300)
df_annual_change[['East Ayrshire', 'South Ayrshire', 'Dumfries and Galloway',
                   'Na h-Eileanan Siar', 'Angus', 'Fife']].plot()

plt.title('Rural annual change')
  
# adding labels to the axes, add a legend
plt.xlabel('Date')
plt.ylabel('Annual_Change')
plt.legend()

# %%
##Rural3
plt.figure(figsize=(16, 8), dpi=300)
df_average_price=df_scotland.pivot(index='Date',columns='Region_Name',values='Average_Price')
df_average_price[['East Ayrshire', 'South Ayrshire', 'Dumfries and Galloway',
                   'Na h-Eileanan Siar', 'Angus', 'Fife']].plot()
plt.title('Rural average price')
#df_average_price.plot()
# Out:
# Text(0.5, 1.0, 'Rural average price')

# %% [markdown]
# 2000-2007: House price bubble
#
# 2007-2009: Financial crash (ONS: the average UK house price dropped by 15% from January 2008 to May 2009)

# %% [markdown]
# In 2021, Scottish Borders reaches higher than pre-2008 which could be affected by Covid Pandenmic
# as more people are working from home and tring to move to countryside for a wider space.

# %%
#Urban is to exclude Rural's 16 regions: Aberdeenshire, Angus, Argyll and Bute, 
#Dumfries and Galloway, East Ayrshire, East Lothian, Fife, Highland, Moray, Na h-Eileanan Siar, 
#Orkney Islands, Perth and Kinross, Scottish Borders, Shetland Islands, South Ayrshire, Stirling
#Clackmannanshire needs to be excluded from both groups.

df_Urban = df_scotland[df_scotland['Region_Name'] != 'Clackmannanshire']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Aberdeenshire']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Angus']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Argyll and Bute']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Dumfries and Galloway']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'East Ayrshire']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'East Lothian']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Fife']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Highland']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Moray']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Na h-Eileanan Siar']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Orkney Islands']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Perth and Kinross']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Scottish Borders']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Shetland Islands']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'South Ayrshire']
df_Urban = df_Urban[df_Urban['Region_Name'] != 'Stirling']
#df_Urban

# %%
#Rural is to exclude Urban's 15 regions: Aberdeen City ,Dundee City, East Dunbartonshire, 
#East Renfrewshire, City of Edinburgh, Falkirk, Glasgow City, Inverclyde, Midlothian, 
#North Ayrshire, North Lanarkshire, Renfrewshire, South Lanarkshire, West Dunbartonshire, West Lothian
#Clackmannanshire needs to be excluded from both groups.

df_Rural = df_scotland[df_scotland['Region_Name'] != 'Clackmannanshire']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'Aberdeen City']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'Dundee City']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'East Dunbartonshire']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'East Renfrewshire']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'City of Edinburgh']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'Falkirk']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'Glasgow City']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'Inverclyde']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'Midlothian']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'North Ayrshire']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'North Lanarkshire']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'Renfrewshire']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'South Lanarkshire']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'West Dunbartonshire']
df_Rural = df_Rural[df_Rural['Region_Name'] != 'West Lothian']
#df_Rural

# %%
##Rural

df_Angus = df_Rural[(df_Rural.Region_Name=="Angus")]
df_Argyll_Bute = df_Rural[(df_Rural.Region_Name=="Argyll and Bute")]
df_Dumfries_Galloway = df_Rural[(df_Rural.Region_Name=="Dumfries and Galloway")]
df_East_Ayrshire = df_Rural[(df_Rural.Region_Name=="East Ayrshire")]
df_East_Lothian = df_Rural[(df_Rural.Region_Name=="East Lothian")]
df_Fife = df_Rural[(df_Rural.Region_Name=="Fife")]
df_Highland = df_Rural[(df_Rural.Region_Name=="Highland")]
df_Moray = df_Rural[(df_Rural.Region_Name=="Moray")]
df_Na_h_Eileanan_Siar = df_Rural[(df_Rural.Region_Name=="Na h-Eileanan Siar")]
df_Orkney= df_Rural[(df_Rural.Region_Name=="Orkney Islands")]
df_Perth_Kinross = df_Rural[(df_Rural.Region_Name=="Perth and Kinross")]
df_Borders = df_Rural[(df_Rural.Region_Name=="Scottish Borders")]
df_Shetland = df_Rural[(df_Rural.Region_Name=="Shetland Islands")]
df_South_Ayrshire = df_Rural[(df_Rural.Region_Name=="South Ayrshire")]
df_Stirling = df_Rural[(df_Rural.Region_Name=="Stirling")]

# this is needed so the row numbers are still in sequence

df_Angus.reset_index(drop=True)
df_Argyll_Bute.reset_index(drop=True)
df_Dumfries_Galloway.reset_index(drop=True)
df_East_Ayrshire.reset_index(drop=True)
df_East_Lothian.reset_index(drop=True)
df_Fife.reset_index(drop=True)
df_Highland.reset_index(drop=True)
df_Moray.reset_index(drop=True)
df_Na_h_Eileanan_Siar.reset_index(drop=True)
df_Orkney.reset_index(drop=True)
df_Perth_Kinross.reset_index(drop=True)
df_Borders.reset_index(drop=True)
df_Shetland.reset_index(drop=True)
df_South_Ayrshire.reset_index(drop=True)
df_Stirling.reset_index(drop=True)
# Out:
#            Date Region_Name  Area_Code  Average_Price  Monthly_Change  \
# 0    2004-01-01    Stirling  S12000030   118836.26450             NaN
# 1    2004-02-01    Stirling  S12000030   108712.32080       -8.519238
# 2    2004-03-01    Stirling  S12000030   108211.38020       -0.460795
# 3    2004-04-01    Stirling  S12000030   108475.96990        0.244512
# 4    2004-05-01    Stirling  S12000030   115511.16370        6.485486
# ..          ...         ...        ...            ...             ...
# 218  2022-03-01    Stirling  S12000030   228450.57620        1.214050
# 219  2022-04-01    Stirling  S12000030   228287.59789       -0.071341
# 220  2022-05-01    Stirling  S12000030   240069.17318        5.160848
# 221  2022-06-01    Stirling  S12000030   244158.11150        1.703233
# 222  2022-07-01    Stirling  S12000030   250316.49005        2.522291
#
#      Annual_Change  Average_Price_SA
# 0              NaN               NaN
# 1              NaN               NaN
# ...

# %%
#Urban includs 15 regions: Aberdeen City ,Dundee City, East Dunbartonshire, 
#East Renfrewshire, City of Edinburgh, Falkirk, Glasgow City, Inverclyde, 
#Midlothian, North Ayrshire, North Lanarkshire, Renfrewshire, South Lanarkshire, 
#West Dunbartonshire, West Lothian

#Rural's 16 regions: Aberdeenshire, Angus, Argyll and Bute, Dumfries and Galloway,
#East Ayrshire, East Lothian, Fife, Highland, Moray, Na h-Eileanan Siar, 
#Orkney Islands, Perth and Kinross, Scottish Borders, Shetland Islands, 
#South Ayrshire, Stirling


#Rural1 :Aberdeenshire

df_Aberdeenshire = df_Rural[(df_Rural.Region_Name=="Aberdeenshire")]
df_Aberdeenshire.reset_index(drop=True)
#print (df_Aberdeenshire)

df_Aberdeenshire_2005 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2005-07-01']
df_Aberdeenshire_annual_change_2005 = df_Aberdeenshire_2005['Annual_Change'].max()
df_Aberdeenshire_Average_Price_2005 = df_Aberdeenshire_2005['Average_Price'].max()
#df_Aberdeenshire_2005 = df_Aberdeenshire_2005.reset_index()
#print (df_Aberdeenshire_2005['Annual_Change'])
#print ('Aberdeenshire 2005-07 annual change:', df_Aberdeenshire_annual_change_2005)
#print ('Aberdeenshire 2005-07 average price:', df_Aberdeenshire_Average_Price_2005)
#print ('')
df_Aberdeenshire_2006 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2006-07-01']
df_Aberdeenshire_annual_change_2006 = df_Aberdeenshire_2006['Annual_Change'].max()
df_Aberdeenshire_Average_Price_2006 = df_Aberdeenshire_2006['Average_Price'].max()
#df_Aberdeenshire_2006 = df_Aberdeenshire_2006.reset_index()
#print ('Aberdeenshire 2006-07 annual change:', df_Aberdeenshire_annual_change_2006)
#print ('Aberdeenshire 2006-07 average price:', df_Aberdeenshire_Average_Price_2006)
#print ('')
#print ('Aberdeenshire 2005-07 to 2006-07 price change:',
#       (df_Aberdeenshire_Average_Price_2006-df_Aberdeenshire_Average_Price_2005)/
#       df_Aberdeenshire_Average_Price_2005 * 100, '%')
#print ('')

df_Aberdeenshire_200712 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2007-12-01']
df_Aberdeenshire_annual_change_200712 = df_Aberdeenshire_200712['Annual_Change'].max()
df_Aberdeenshire_Average_Price_200712 = df_Aberdeenshire_200712['Average_Price'].max()
#df_Aberdeenshire_2007 = df_Aberdeenshire_2007.reset_index()
#print ('Aberdeenshire 2007-07 annual change:', df_Aberdeenshire_annual_change_2007)
#print ('Aberdeenshire 2007-07 average price:', df_Aberdeenshire_Average_Price_2007)
#print ('')
#print ('Aberdeenshire 2006-07 to 2007-07 price change:',
#       (df_Aberdeenshire_Average_Price_2007-df_Aberdeenshire_Average_Price_2006)/
#       df_Aberdeenshire_Average_Price_2006 * 100, '%')
#print ('')
#print ('Aberdeenshire 2005-07 to 2007-12 price change:',
#       (df_Aberdeenshire_Average_Price_200712-df_Aberdeenshire_Average_Price_2005)/
#       df_Aberdeenshire_Average_Price_2005 * 100, '%')
#print ('')

df_Aberdeenshire_200807 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2008-07-01']
df_Aberdeenshire_annual_change_200807 = df_Aberdeenshire_200807['Annual_Change'].max()
df_Aberdeenshire_Average_Price_200807 = df_Aberdeenshire_200807['Average_Price'].max()
#df_Aberdeenshire_2008 = df_Aberdeenshire_2008.reset_index()
#print ('Aberdeenshire 2008-07 annual change:', df_Aberdeenshire_annual_change_200807)
#print ('')
print ('Aberdeenshire 2005-07 to 2008-07 price change:',
       (df_Aberdeenshire_Average_Price_200807-df_Aberdeenshire_Average_Price_2005)/
       df_Aberdeenshire_Average_Price_2005 * 100, '%')
print ('Aberdeenshire 2008-07 average price:', df_Aberdeenshire_Average_Price_200807)
print ('')

df_Aberdeenshire_200812 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2008-12-01']
df_Aberdeenshire_annual_change_200812 = df_Aberdeenshire_200812['Annual_Change'].max()
df_Aberdeenshire_Average_Price_200812 = df_Aberdeenshire_200812['Average_Price'].max()
#df_Aberdeenshire_2008 = df_Aberdeenshire_2008.reset_index()
#print ('Aberdeenshire 2008-12 annual change:', df_Aberdeenshire_annual_change_200812)
#print ('Aberdeenshire 2008-12 average price:', df_Aberdeenshire_Average_Price_200812)
#print ('')
#print ('Aberdeenshire 2008-07 to 2008-12 price change:',
#       (df_Aberdeenshire_Average_Price_200812-df_Aberdeenshire_Average_Price_200807)/
#       df_Aberdeenshire_Average_Price_200807 * 100, '%')
#print ('')

df_Aberdeenshire_200907 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2009-07-01']
df_Aberdeenshire_annual_change_200907 = df_Aberdeenshire_200907['Annual_Change'].max()
df_Aberdeenshire_Average_Price_200907 = df_Aberdeenshire_200907['Average_Price'].max()
#df_Aberdeenshire_2009 = df_Aberdeenshire_2009.reset_index()
#print ('Aberdeenshire 2009-07 annual change:', df_Aberdeenshire_annual_change_2009)
#print ('')
#print ('Aberdeenshire 2008-12 to 2009-07 price change:',
#       (df_Aberdeenshire_Average_Price_200907-df_Aberdeenshire_Average_Price_200812)/
#       df_Aberdeenshire_Average_Price_200812 * 100, '%')
#print ('')
print ('Aberdeenshire 2008-07 to 2009-07 price change:',
       (df_Aberdeenshire_Average_Price_200907-df_Aberdeenshire_Average_Price_200807)/
       df_Aberdeenshire_Average_Price_200807 * 100, '%')
print ('Aberdeenshire 2009-07 average price:', df_Aberdeenshire_Average_Price_200907)
print ('')

df_Aberdeenshire_200912 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2009-12-01']
df_Aberdeenshire_annual_change_200912 = df_Aberdeenshire_200912['Annual_Change'].max()
df_Aberdeenshire_Average_Price_200912 = df_Aberdeenshire_200912['Average_Price'].max()
#df_Aberdeenshire_2009 = df_Aberdeenshire_2009.reset_index()
#print ('Aberdeenshire 2009-07 annual change:', df_Aberdeenshire_annual_change_2009)
print ('Aberdeenshire 2009-12 average price:', df_Aberdeenshire_Average_Price_200912)
#print ('')
#print ('Aberdeenshire 2009-07 to 2009-12 price change:',
#       (df_Aberdeenshire_Average_Price_200912-df_Aberdeenshire_Average_Price_200907)/
#       df_Aberdeenshire_Average_Price_200907 * 100, '%')
#print ('')

df_Aberdeenshire_2010 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2010-07-01']
df_Aberdeenshire_Average_Price_2010 = df_Aberdeenshire_2010['Average_Price'].max()
#df_Aberdeenshire_2010 = df_Aberdeenshire_2010.reset_index()
print ('Aberdeenshire 2008-07 to 2010-07 price change:',
       (df_Aberdeenshire_Average_Price_2010-df_Aberdeenshire_Average_Price_200807)/
       df_Aberdeenshire_Average_Price_200807 * 100, '%')
print ('Aberdeenshire 2010-07 average price:', df_Aberdeenshire_Average_Price_2010)
print ('')

df_Aberdeenshire_2011 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2011-07-01']
df_Aberdeenshire_2011 = df_Aberdeenshire_2011['Annual_Change'].max()
#df_Aberdeenshire_2011 = df_Aberdeenshire_2011.reset_index()

df_Aberdeenshire_2012 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2012-07-01']
df_Aberdeenshire_Average_Price_2012 = df_Aberdeenshire_2012['Average_Price'].max()
#df_Aberdeenshire_2012 = df_Aberdeenshire_2012.reset_index()
print ('Aberdeenshire 2008-07 to 2012-07 price change:',
       (df_Aberdeenshire_Average_Price_2012-df_Aberdeenshire_Average_Price_200807)/
       df_Aberdeenshire_Average_Price_200807 * 100, '%')
print ('Aberdeenshire 2012-07 average price:', df_Aberdeenshire_Average_Price_2012)
print ('')

df_Aberdeenshire_2013 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2013-07-01']
df_Aberdeenshire_2013 = df_Aberdeenshire_2013['Annual_Change'].max()
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013.reset_index()

df_Aberdeenshire_2014 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2014-07-01']
df_Aberdeenshire_Average_Price_2014 = df_Aberdeenshire_2014['Average_Price'].max()
#df_Aberdeenshire_2014 = df_Aberdeenshire_2014.reset_index()
print ('Aberdeenshire 2008-07 to 2014-07 price change:',
       (df_Aberdeenshire_Average_Price_2014-df_Aberdeenshire_Average_Price_200807)/
       df_Aberdeenshire_Average_Price_200907 * 100, '%')
print ('Aberdeenshire 2014-07 average price:', df_Aberdeenshire_Average_Price_2014)
print ('')

df_Aberdeenshire_2015 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2015-07-01']
df_Aberdeenshire_2015 = df_Aberdeenshire_2015['Annual_Change'].max()
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015.reset_index()

df_Aberdeenshire_2016 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2016-07-01']
df_Aberdeenshire_Average_Price_2016 = df_Aberdeenshire_2016['Average_Price'].max()
#df_Aberdeenshire_2016 = df_Aberdeenshire_2016.reset_index()
print ('Aberdeenshire 2008-07 to 2016-07 price change:',
       (df_Aberdeenshire_Average_Price_2016-df_Aberdeenshire_Average_Price_200807)/
       df_Aberdeenshire_Average_Price_200907 * 100, '%')
print ('Aberdeenshire 2016-07 average price:', df_Aberdeenshire_Average_Price_2016)
print ('')

df_Aberdeenshire_2017 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2017-07-01']
df_Aberdeenshire_2017 = df_Aberdeenshire_2017['Annual_Change'].max()
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017.reset_index()

df_Aberdeenshire_2018 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2018-07-01']
df_Aberdeenshire_Average_Price_2018 = df_Aberdeenshire_2018['Average_Price'].max()
#df_Aberdeenshire_2018 = df_Aberdeenshire_2018.reset_index()
print ('Aberdeenshire 2008-07 to 2018-07 price change:',
       (df_Aberdeenshire_Average_Price_2018-df_Aberdeenshire_Average_Price_200807)/
       df_Aberdeenshire_Average_Price_200807 * 100, '%')
print ('Aberdeenshire 2018-07 average price:', df_Aberdeenshire_Average_Price_2018)
print ('')

df_Aberdeenshire_201907 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2019-07-01']
df_Aberdeenshire_Average_Price_201907 = df_Aberdeenshire_201907['Average_Price'].max()
#df_Aberdeenshire_2019 = df_Aberdeenshire_2019.reset_index()
print ('Aberdeenshire 2008-07 to 2019-07 price change:',
       (df_Aberdeenshire_Average_Price_201907-df_Aberdeenshire_Average_Price_200807)/
       df_Aberdeenshire_Average_Price_200807 * 100, '%')
print ('Aberdeenshire 2019-07 average price:', df_Aberdeenshire_Average_Price_201907)
#print ('')

df_Aberdeenshire_201912 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2019-12-01']
df_Aberdeenshire_Average_Price_201912 = df_Aberdeenshire_201912['Average_Price'].max()
#df_Aberdeenshire_2019 = df_Aberdeenshire_2019.reset_index()
#print ('Aberdeenshire 2019-07 to 2019-12 price change:',
#       (df_Aberdeenshire_Average_Price_201912-df_Aberdeenshire_Average_Price_201907)/
#       df_Aberdeenshire_Average_Price_201907 * 100, '%')
print ('Aberdeenshire 2019-12 average price:', df_Aberdeenshire_Average_Price_201912)
print ('')


df_Aberdeenshire_202007 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2020-07-01']
df_Aberdeenshire_Average_Price_202007 = df_Aberdeenshire_202007['Average_Price'].max()
#df_Aberdeenshire_2020 = df_Aberdeenshire_2020.reset_index()
print ('Aberdeenshire 2019-07 to 2020-07 price change:',
       (df_Aberdeenshire_Average_Price_202007-df_Aberdeenshire_Average_Price_201907)/
       df_Aberdeenshire_Average_Price_201907 * 100, '%')
print ('Aberdeenshire 2020-07 average price:', df_Aberdeenshire_Average_Price_202007)
print ('')

#df_Aberdeenshire_202012 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2020-12-01']
#df_Aberdeenshire_Average_Price_202012 = df_Aberdeenshire_202012['Average_Price'].max()
#df_Aberdeenshire_2020 = df_Aberdeenshire_2020.reset_index()
#print ('Aberdeenshire 2020-07 to 2020-12 price change:',
#       (df_Aberdeenshire_Average_Price_202012-df_Aberdeenshire_Average_Price_202007)/
#       df_Aberdeenshire_Average_Price_202007 * 100, '%')
print ('')

df_Aberdeenshire_2021 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2021-07-01']
df_Aberdeenshire_Average_Price_2021 = df_Aberdeenshire_2021['Average_Price'].max()
#df_Aberdeenshire_2021 = df_Aberdeenshire_2021.reset_index()

print ('Aberdeenshire 2019-07 to 2021-07 price change:',
       (df_Aberdeenshire_Average_Price_2021-df_Aberdeenshire_Average_Price_201907)/
       df_Aberdeenshire_Average_Price_201907 * 100, '%')
print ('Aberdeenshire 2021-07 average price:', df_Aberdeenshire_Average_Price_2021)
print ('')


df_Aberdeenshire_2022 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2022-07-01']
df_Aberdeenshire_Average_Price_2022 = df_Aberdeenshire_2022['Average_Price'].max()
#df_Aberdeenshire_2022 = df_Aberdeenshire_2022.reset_index

print ('Aberdeenshire 2019-07 to 2022-07 price change:',
       (df_Aberdeenshire_Average_Price_2022-df_Aberdeenshire_Average_Price_201907)/
       df_Aberdeenshire_Average_Price_201907 * 100, '%')
print ('Aberdeenshire 2022-07 average price:', df_Aberdeenshire_Average_Price_2022)
print ('')

print ('Aberdeenshire 2008-07 to 2022-07 price change:',
       (df_Aberdeenshire_Average_Price_2022-df_Aberdeenshire_Average_Price_200807)/
       df_Aberdeenshire_Average_Price_200807 * 100, '%')
print ('')
# Out:
# Aberdeenshire 2005-07 to 2008-07 price change: 63.91404919285159 %
# Aberdeenshire 2008-07 average price: 177729.5545
#
# Aberdeenshire 2008-07 to 2009-07 price change: -5.199589582046685 %
# Aberdeenshire 2009-07 average price: 168488.3471
#
# Aberdeenshire 2009-12 average price: 174470.1876
# Aberdeenshire 2008-07 to 2010-07 price change: 0.995623718845248 %
# Aberdeenshire 2010-07 average price: 179499.0721
#
# Aberdeenshire 2008-07 to 2012-07 price change: 0.4083426091072489 %
# Aberdeenshire 2012-07 average price: 178455.3
#
# Aberdeenshire 2008-07 to 2014-07 price change: 12.124794296827671 %
# Aberdeenshire 2014-07 average price: 198158.42
#
# Aberdeenshire 2008-07 to 2016-07 price change: 12.856409581336555 %
# Aberdeenshire 2016-07 average price: 199391.1065
#
# Aberdeenshire 2008-07 to 2018-07 price change: 5.744713043772363 %
# Aberdeenshire 2018-07 average price: 187939.6074
#
# Aberdeenshire 2008-07 to 2019-07 price change: 6.787925640133191 %
# ...

# %% [raw]
# Aberdeenshire Average price
#
# 2008-07: £177729.5545(base)
# Financial crisis - a year drop
# 2009-07: £168488.3471(-5.2%)
# a year return to pre-2008
# 2010-07: £179499.0721(0.996%)
# 2014-07: £198158.42(12.12%)
# 2016-07: £199391.1065(12.86%)
# 2018-07: £187939.6074(5.74%)
#
# 2019-07: £189793.7045(base)
# Covid Pandenmic - a year drop
# 2020-07: 176720.9322(-6.89%)
# a year return to pre-Covid
# 2021-07: 192388.34691(1.37)
# 2022-07: 203980.8761(7.48%)

# %%
#Urban includs 15 regions: Aberdeen City ,Dundee City, East Dunbartonshire, 
#East Renfrewshire, City of Edinburgh, Falkirk, Glasgow City, Inverclyde, 
#Midlothian, North Ayrshire, North Lanarkshire, Renfrewshire, South Lanarkshire, 
#West Dunbartonshire, West Lothian

#Rural's 16 regions: Aberdeenshire, Angus, Argyll and Bute, Dumfries and Galloway,
#East Ayrshire, East Lothian, Fife, Highland, Moray, Na h-Eileanan Siar, 
#Orkney Islands, Perth and Kinross, Scottish Borders, Shetland Islands, 
#South Ayrshire, Stirling


#Rural2 :Angus

df_Angus = df_Rural[(df_Rural.Region_Name=="Angus")]
df_Angus.reset_index(drop=True)
#print (df_Aberdeenshire)

df_Angus_2005 = df_Angus[df_Angus['Date'] == '2005-07-01']
df_Angus_annual_change_2005 = df_Angus_2005['Annual_Change'].max()
df_Angus_Average_Price_2005 = df_Angus_2005['Average_Price'].max()

df_Angus_200807 = df_Angus[df_Angus['Date'] == '2008-07-01']
df_Angus_annual_change_200807 = df_Angus_200807['Annual_Change'].max()
df_Angus_Average_Price_200807 = df_Angus_200807['Average_Price'].max()

print ('Angus 2005-07 to 2008-07 price change:',
       (df_Angus_Average_Price_200807-df_Angus_Average_Price_2005)/
       df_Angus_Average_Price_2005 * 100, '%')
print ('Angus 2008-07 average price:', df_Angus_Average_Price_200807)
print ('')

df_Angus_200907 = df_Angus[df_Angus['Date'] == '2009-07-01']
df_Angus_annual_change_200907 = df_Angus_200907['Annual_Change'].max()
df_Angus_Average_Price_200907 = df_Angus_200907['Average_Price'].max()

print ('Angus 2008-07 to 2009-07 price change:',
       (df_Angus_Average_Price_200907-df_Angus_Average_Price_200807)/
       df_Angus_Average_Price_200807 * 100, '%')
print ('Angus 2009-07 average price:', df_Angus_Average_Price_200907)
print ('')

df_Angus_200912 = df_Angus[df_Angus['Date'] == '2009-12-01']
df_Angus_annual_change_200912 = df_Angus_200912['Annual_Change'].max()
df_Angus_Average_Price_200912 = df_Angus_200912['Average_Price'].max()

print ('Angus 2009-12 average price:', df_Angus_Average_Price_200912)

df_Angus_2010 = df_Angus[df_Angus['Date'] == '2010-07-01']
df_Angus_Average_Price_2010 = df_Angus_2010['Average_Price'].max()

print ('Angus 2008-07 to 2010-07 price change:',
       (df_Angus_Average_Price_2010-df_Angus_Average_Price_200807)/
       df_Angus_Average_Price_200807 * 100, '%')
print ('Angus 2010-07 average price:', df_Angus_Average_Price_2010)
print ('')

df_Angus_2011 = df_Angus[df_Angus['Date'] == '2011-07-01']
df_Angus_2011 = df_Angus_2011['Annual_Change'].max()

df_Angus_2012 = df_Angus[df_Angus['Date'] == '2012-07-01']
df_Angus_Average_Price_2012 = df_Angus_2012['Average_Price'].max()

print ('Angus 2008-07 to 2012-07 price change:',
       (df_Angus_Average_Price_2012-df_Angus_Average_Price_200807)/
       df_Angus_Average_Price_200807 * 100, '%')
print ('Angus 2012-07 average price:', df_Angus_Average_Price_2012)
print ('')

#df_Angus_2013 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2013-07-01']
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013['Annual_Change'].max()
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013.reset_index()

df_Angus_2014 = df_Angus[df_Angus['Date'] == '2014-07-01']
df_Angus_Average_Price_2014 = df_Angus_2014['Average_Price'].max()
#df_Aberdeenshire_2014 = df_Aberdeenshire_2014.reset_index()
print ('Angus 2008-07 to 2014-07 price change:',
       (df_Angus_Average_Price_2014-df_Angus_Average_Price_200807)/
       df_Angus_Average_Price_200907 * 100, '%')
print ('Angus 2014-07 average price:', df_Angus_Average_Price_2014)
print ('')

#df_Aberdeenshire_2015 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2015-07-01']
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015['Annual_Change'].max()
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015.reset_index()

df_Angus_2016 = df_Angus[df_Angus['Date'] == '2016-07-01']
df_Angus_Average_Price_2016 = df_Angus_2016['Average_Price'].max()

print ('Angus 2008-07 to 2016-07 price change:',
       (df_Angus_Average_Price_2016-df_Angus_Average_Price_200807)/
       df_Angus_Average_Price_200907 * 100, '%')
print ('Angus 2016-07 average price:', df_Angus_Average_Price_2016)
print ('')

#df_Angus_2017 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2017-07-01']
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017['Annual_Change'].max()
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017.reset_index()

df_Angus_2018 = df_Angus[df_Angus['Date'] == '2018-07-01']
df_Angus_Average_Price_2018 = df_Angus_2018['Average_Price'].max()

print ('Angus 2008-07 to 2018-07 price change:',
       (df_Angus_Average_Price_2018-df_Angus_Average_Price_200807)/
       df_Angus_Average_Price_200807 * 100, '%')
print ('Angus 2018-07 average price:', df_Angus_Average_Price_2018)
print ('')

df_Angus_201907 = df_Angus[df_Angus['Date'] == '2019-07-01']
df_Angus_Average_Price_201907 = df_Angus_201907['Average_Price'].max()

print ('Angus 2008-07 to 2019-07 price change:',
       (df_Angus_Average_Price_201907-df_Angus_Average_Price_200807)/
       df_Angus_Average_Price_200807 * 100, '%')
print ('Angus 2019-07 average price:', df_Angus_Average_Price_201907)
#print ('')

df_Angus_201912 = df_Angus[df_Angus['Date'] == '2019-12-01']
df_Angus_Average_Price_201912 = df_Angus_201912['Average_Price'].max()

print ('Angus 2019-12 average price:', df_Angus_Average_Price_201912)
print ('')

df_Angus_202007 = df_Angus[df_Angus['Date'] == '2020-07-01']
df_Angus_Average_Price_202007 = df_Angus_202007['Average_Price'].max()

print ('Angus 2019-07 to 2020-07 price change:',
       (df_Angus_Average_Price_202007-df_Angus_Average_Price_201907)/
       df_Angus_Average_Price_201907 * 100, '%')
print ('Angus 2020-07 average price:', df_Angus_Average_Price_202007)
print ('')

#df_Aberdeenshire_202012 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2020-12-01']
#df_Aberdeenshire_Average_Price_202012 = df_Aberdeenshire_202012['Average_Price'].max()
#df_Aberdeenshire_2020 = df_Aberdeenshire_2020.reset_index()
#print ('Aberdeenshire 2020-07 to 2020-12 price change:',
#       (df_Aberdeenshire_Average_Price_202012-df_Aberdeenshire_Average_Price_202007)/
#       df_Aberdeenshire_Average_Price_202007 * 100, '%')
#print ('')

df_Angus_2021 = df_Angus[df_Angus['Date'] == '2021-07-01']
df_Angus_Average_Price_2021 = df_Angus_2021['Average_Price'].max()

print ('Angus 2019-07 to 2021-07 price change:',
       (df_Angus_Average_Price_2021-df_Angus_Average_Price_201907)/
       df_Angus_Average_Price_201907 * 100, '%')
print ('Angus 2021-07 average price:', df_Angus_Average_Price_2021)
print ('')

df_Angus_2022 = df_Angus[df_Angus['Date'] == '2022-07-01']
df_Angus_Average_Price_2022 = df_Angus_2022['Average_Price'].max()

print ('Angus 2019-07 to 2022-07 price change:',
       (df_Angus_Average_Price_2022-df_Angus_Average_Price_201907)/
       df_Angus_Average_Price_201907 * 100, '%')
print ('Angus 2022-07 average price:', df_Angus_Average_Price_2022)
print ('')

print ('Angus 2008-07 to 2022-07 price change:',
       (df_Angus_Average_Price_2022-df_Angus_Average_Price_200807)/
       df_Angus_Average_Price_200807 * 100, '%')
print ('')
# Out:
# Angus 2005-07 to 2008-07 price change: 39.61407011086426 %
# Angus 2008-07 average price: 134546.2421
#
# Angus 2008-07 to 2009-07 price change: -3.9877711307702164 %
# Angus 2009-07 average price: 129180.8459
#
# Angus 2009-12 average price: 133509.6046
# Angus 2008-07 to 2010-07 price change: -0.12108350070374407 %
# Angus 2010-07 average price: 134383.3288
#
# Angus 2008-07 to 2012-07 price change: -4.556001791149244 %
# Angus 2012-07 average price: 128416.3129
#
# Angus 2008-07 to 2014-07 price change: 1.769244336555304 %
# Angus 2014-07 average price: 136831.7669
#
# Angus 2008-07 to 2016-07 price change: 3.505772909635349 %
# Angus 2016-07 average price: 139075.0292
#
# Angus 2008-07 to 2018-07 price change: 9.080510766639987 %
# Angus 2018-07 average price: 146763.7281
#
# Angus 2008-07 to 2019-07 price change: 10.260516298730577 %
# Angus 2019-07 average price: 148351.3812
# Angus 2019-12 average price: 145671.5838
#
# ...

# %%
#Urban includs 15 regions: Aberdeen City ,Dundee City, East Dunbartonshire, 
#East Renfrewshire, City of Edinburgh, Falkirk, Glasgow City, Inverclyde, 
#Midlothian, North Ayrshire, North Lanarkshire, Renfrewshire, South Lanarkshire, 
#West Dunbartonshire, West Lothian

#Rural's 16 regions: Aberdeenshire, Angus, Argyll and Bute, Dumfries and Galloway,
#East Ayrshire, East Lothian, Fife, Highland, Moray, Na h-Eileanan Siar, 
#Orkney Islands, Perth and Kinross, Scottish Borders, Shetland Islands, 
#South Ayrshire, Stirling


#Rural3 :Argyll and Bute

df_Argyll_Bute = df_Rural[(df_Rural.Region_Name=="Argyll and Bute")]
df_Argyll_Bute.reset_index(drop=True)

df_Argyll_Bute_2005 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2005-07-01']
df_Argyll_Bute_annual_change_2005 = df_Argyll_Bute_2005['Annual_Change'].max()
df_Argyll_Bute_Average_Price_2005 = df_Argyll_Bute_2005['Average_Price'].max()

df_Argyll_Bute_200807 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2008-07-01']
df_Argyll_Bute_annual_change_200807 = df_Argyll_Bute_200807['Annual_Change'].max()
df_Argyll_Bute_Average_Price_200807 = df_Argyll_Bute_200807['Average_Price'].max()

print ('Argyll and Bute 2005-07 to 2008-07 price change:',
       (df_Argyll_Bute_Average_Price_200807-df_Argyll_Bute_Average_Price_2005)/
       df_Argyll_Bute_Average_Price_2005 * 100, '%')
print ('Argyll and Bute 2008-07 average price:', df_Argyll_Bute_Average_Price_200807)
print ('')

df_Argyll_Bute_200907 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2009-07-01']
df_Argyll_Bute_annual_change_200907 = df_Argyll_Bute_200907['Annual_Change'].max()
df_Argyll_Bute_Average_Price_200907 = df_Argyll_Bute_200907['Average_Price'].max()

print ('Argyll and Bute 2008-07 to 2009-07 price change:',
       (df_Argyll_Bute_Average_Price_200907-df_Argyll_Bute_Average_Price_200807)/
       df_Argyll_Bute_Average_Price_200807 * 100, '%')
print ('Argyll and Bute 2009-07 average price:', df_Argyll_Bute_Average_Price_200907)
print ('')

df_Argyll_Bute_200912 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2009-12-01']
df_Argyll_Bute_annual_change_200912 = df_Argyll_Bute_200912['Annual_Change'].max()
df_Argyll_Bute_Average_Price_200912 = df_Argyll_Bute_200912['Average_Price'].max()

print ('Argyll and Bute 2009-12 average price:', df_Argyll_Bute_Average_Price_200912)

df_Argyll_Bute_2010 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2010-07-01']
df_Argyll_Bute_Average_Price_2010 = df_Argyll_Bute_2010['Average_Price'].max()

print ('Argyll and Bute 2008-07 to 2010-07 price change:',
       (df_Argyll_Bute_Average_Price_2010-df_Argyll_Bute_Average_Price_200807)/
       df_Argyll_Bute_Average_Price_200807 * 100, '%')
print ('Argyll and Bute 2010-07 average price:', df_Argyll_Bute_Average_Price_2010)
print ('')

df_Argyll_Bute_2011 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2011-07-01']
df_Argyll_Bute_2011 = df_Argyll_Bute_2011['Annual_Change'].max()

df_Argyll_Bute_2012 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2012-07-01']
df_Argyll_Bute_Average_Price_2012 = df_Argyll_Bute_2012['Average_Price'].max()

print ('Argyll and Bute 2008-07 to 2012-07 price change:',
       (df_Argyll_Bute_Average_Price_2012-df_Argyll_Bute_Average_Price_200807)/
       df_Argyll_Bute_Average_Price_200807 * 100, '%')
print ('Argyll and Bute 2012-07 average price:', df_Argyll_Bute_Average_Price_2012)
print ('')

#df_Angus_2013 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2013-07-01']
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013['Annual_Change'].max()
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013.reset_index()

df_Argyll_Bute_2014 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2014-07-01']
df_Argyll_Bute_Average_Price_2014 = df_Argyll_Bute_2014['Average_Price'].max()
#df_Aberdeenshire_2014 = df_Aberdeenshire_2014.reset_index()
print ('Argyll and Bute 2008-07 to 2014-07 price change:',
       (df_Argyll_Bute_Average_Price_2014-df_Argyll_Bute_Average_Price_200807)/
       df_Argyll_Bute_Average_Price_200907 * 100, '%')
print ('Argyll and Bute 2014-07 average price:', df_Argyll_Bute_Average_Price_2014)
print ('')

#df_Aberdeenshire_2015 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2015-07-01']
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015['Annual_Change'].max()
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015.reset_index()

df_Argyll_Bute_2016 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2016-07-01']
df_Argyll_Bute_Average_Price_2016 = df_Argyll_Bute_2016['Average_Price'].max()

print ('Argyll and Bute 2008-07 to 2016-07 price change:',
       (df_Argyll_Bute_Average_Price_2016-df_Argyll_Bute_Average_Price_200807)/
       df_Argyll_Bute_Average_Price_200907 * 100, '%')
print ('Argyll and Bute 2016-07 average price:', df_Argyll_Bute_Average_Price_2016)
print ('')

#df_Angus_2017 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2017-07-01']
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017['Annual_Change'].max()
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017.reset_index()

df_Argyll_Bute_2018 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2018-07-01']
df_Argyll_Bute_Average_Price_2018 = df_Argyll_Bute_2018['Average_Price'].max()

print ('Argyll and Bute 2008-07 to 2018-07 price change:',
       (df_Argyll_Bute_Average_Price_2018-df_Argyll_Bute_Average_Price_200807)/
       df_Argyll_Bute_Average_Price_200807 * 100, '%')
print ('Argyll and Bute 2018-07 average price:', df_Argyll_Bute_Average_Price_2018)
print ('')

df_Argyll_Bute_201907 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2019-07-01']
df_Argyll_Bute_Average_Price_201907 = df_Argyll_Bute_201907['Average_Price'].max()

print ('Argyll and Bute 2008-07 to 2019-07 price change:',
       (df_Argyll_Bute_Average_Price_201907-df_Argyll_Bute_Average_Price_200807)/
       df_Argyll_Bute_Average_Price_200807 * 100, '%')
print ('Argyll and Bute 2019-07 average price:', df_Argyll_Bute_Average_Price_201907)
#print ('')

df_Argyll_Bute_201912 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2019-12-01']
df_Argyll_Bute_Average_Price_201912 = df_Argyll_Bute_201912['Average_Price'].max()

print ('Argyll and Bute 2019-12 average price:', df_Argyll_Bute_Average_Price_201912)
print ('')

df_Argyll_Bute_202007 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2020-07-01']
df_Argyll_Bute_Average_Price_202007 = df_Argyll_Bute_202007['Average_Price'].max()

print ('Argyll and Bute 2019-07 to 2020-07 price change:',
       (df_Argyll_Bute_Average_Price_202007-df_Argyll_Bute_Average_Price_201907)/
       df_Argyll_Bute_Average_Price_201907 * 100, '%')
print ('Argyll and Bute 2020-07 average price:', df_Argyll_Bute_Average_Price_202007)
print ('')

#df_Aberdeenshire_202012 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2020-12-01']
#df_Aberdeenshire_Average_Price_202012 = df_Aberdeenshire_202012['Average_Price'].max()
#df_Aberdeenshire_2020 = df_Aberdeenshire_2020.reset_index()
#print ('Aberdeenshire 2020-07 to 2020-12 price change:',
#       (df_Aberdeenshire_Average_Price_202012-df_Aberdeenshire_Average_Price_202007)/
#       df_Aberdeenshire_Average_Price_202007 * 100, '%')
#print ('')

df_Argyll_Bute_2021 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2021-07-01']
df_Argyll_Bute_Average_Price_2021 = df_Argyll_Bute_2021['Average_Price'].max()

print ('Argyll and Bute 2019-07 to 2021-07 price change:',
       (df_Argyll_Bute_Average_Price_2021-df_Argyll_Bute_Average_Price_201907)/
       df_Argyll_Bute_Average_Price_201907 * 100, '%')
print ('Argyll and Bute 2021-07 average price:', df_Argyll_Bute_Average_Price_2021)
print ('')

df_Argyll_Bute_2022 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2022-07-01']
df_Argyll_Bute_Average_Price_2022 = df_Argyll_Bute_2022['Average_Price'].max()

print ('Argyll and Bute 2019-07 to 2022-07 price change:',
       (df_Argyll_Bute_Average_Price_2022-df_Argyll_Bute_Average_Price_201907)/
       df_Argyll_Bute_Average_Price_201907 * 100, '%')
print ('Argyll and Bute 2022-07 average price:', df_Argyll_Bute_Average_Price_2022)
print ('')

print ('Argyll and Bute 2008-07 to 2022-07 price change:',
       (df_Argyll_Bute_Average_Price_2022-df_Argyll_Bute_Average_Price_200807)/
       df_Argyll_Bute_Average_Price_200807 * 100, '%')
print ('')
# Out:
# Argyll and Bute 2005-07 to 2008-07 price change: 21.380951211287865 %
# Argyll and Bute 2008-07 average price: 140791.8845
#
# Argyll and Bute 2008-07 to 2009-07 price change: -7.137503866566954 %
# Argyll and Bute 2009-07 average price: 130742.8583
#
# Argyll and Bute 2009-12 average price: 129877.2878
# Argyll and Bute 2008-07 to 2010-07 price change: -4.393882802243457 %
# Argyll and Bute 2010-07 average price: 134605.6541
#
# Argyll and Bute 2008-07 to 2012-07 price change: -12.579500773711139 %
# Argyll and Bute 2012-07 average price: 123080.9683
#
# Argyll and Bute 2008-07 to 2014-07 price change: -10.561631112817718 %
# Argyll and Bute 2014-07 average price: 126983.3061
#
# Argyll and Bute 2008-07 to 2016-07 price change: -6.4825797066117685 %
# Argyll and Bute 2016-07 average price: 132316.3745
#
# Argyll and Bute 2008-07 to 2018-07 price change: -1.3547832013001992 %
# Argyll and Bute 2018-07 average price: 138884.4597
#
# ...

# %%
#Urban includs 15 regions: Aberdeen City ,Dundee City, East Dunbartonshire, 
#East Renfrewshire, City of Edinburgh, Falkirk, Glasgow City, Inverclyde, 
#Midlothian, North Ayrshire, North Lanarkshire, Renfrewshire, South Lanarkshire, 
#West Dunbartonshire, West Lothian

#Rural's 16 regions: Aberdeenshire, Angus, Argyll and Bute, Dumfries and Galloway,
#East Ayrshire, East Lothian, Fife, Highland, Moray, Na h-Eileanan Siar, 
#Orkney Islands, Perth and Kinross, Scottish Borders, Shetland Islands, 
#South Ayrshire, Stirling


#Rural3 :Dumfries and Galloway

df_Dumfries_Galloway = df_Rural[(df_Rural.Region_Name=="Dumfries and Galloway")]
df_Dumfries_Galloway.reset_index(drop=True)

df_Dumfries_Galloway_2005 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2005-07-01']
df_Dumfries_Galloway_annual_change_2005 = df_Dumfries_Galloway_2005['Annual_Change'].max()
df_Dumfries_Galloway_Average_Price_2005 = df_Dumfries_Galloway_2005['Average_Price'].max()

df_Dumfries_Galloway_200807 = df_Argyll_Bute[df_Argyll_Bute['Date'] == '2008-07-01']
df_Dumfries_Galloway_annual_change_200807 = df_Dumfries_Galloway_200807['Annual_Change'].max()
df_Dumfries_Galloway_Average_Price_200807 = df_Dumfries_Galloway_200807['Average_Price'].max()

print ('Dumfries and Galloway 2005-07 to 2008-07 price change:',
       (df_Dumfries_Galloway_Average_Price_200807-df_Dumfries_Galloway_Average_Price_2005)/
       df_Dumfries_Galloway_Average_Price_2005 * 100, '%')
print ('Dumfries and Galloway 2008-07 average price:', df_Dumfries_Galloway_Average_Price_200807)
print ('')

df_Dumfries_Galloway_200907 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2009-07-01']
df_Dumfries_Galloway_annual_change_200907 = df_Dumfries_Galloway_200907['Annual_Change'].max()
df_Dumfries_Galloway_Average_Price_200907 = df_Dumfries_Galloway_200907['Average_Price'].max()

print ('Dumfries and Galloway 2008-07 to 2009-07 price change:',
       (df_Dumfries_Galloway_Average_Price_200907-df_Dumfries_Galloway_Average_Price_200807)/
       df_Dumfries_Galloway_Average_Price_200807 * 100, '%')
print ('Dumfries and Galloway 2009-07 average price:', df_Dumfries_Galloway_Average_Price_200907)
print ('')

df_Dumfries_Galloway_200912 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2009-12-01']
df_Dumfries_Galloway_annual_change_200912 = df_Dumfries_Galloway_200912['Annual_Change'].max()
df_Dumfries_Galloway_Average_Price_200912 = df_Dumfries_Galloway_200912['Average_Price'].max()

print ('Dumfries and Galloway 2009-12 average price:', df_Dumfries_Galloway_Average_Price_200912)

df_Dumfries_Galloway_2010 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2010-07-01']
df_Dumfries_Galloway_Average_Price_2010 = df_Dumfries_Galloway_2010['Average_Price'].max()

print ('Dumfries and Galloway 2008-07 to 2010-07 price change:',
       (df_Dumfries_Galloway_Average_Price_2010-df_Dumfries_Galloway_Average_Price_200807)/
       df_Dumfries_Galloway_Average_Price_200807 * 100, '%')
print ('Dumfries and Galloway 2010-07 average price:', df_Dumfries_Galloway_Average_Price_2010)
print ('')

df_Dumfries_Galloway_2011 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2011-07-01']
df_Dumfries_Galloway_2011 = df_Dumfries_Galloway_2011['Annual_Change'].max()

df_Dumfries_Galloway_2012 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2012-07-01']
df_Dumfries_Galloway_Average_Price_2012 = df_Dumfries_Galloway_2012['Average_Price'].max()

print ('Dumfries and Galloway 2008-07 to 2012-07 price change:',
       (df_Dumfries_Galloway_Average_Price_2012-df_Dumfries_Galloway_Average_Price_200807)/
       df_Dumfries_Galloway_Average_Price_200807 * 100, '%')
print ('Dumfries and Galloway 2012-07 average price:', df_Dumfries_Galloway_Average_Price_2012)
print ('')

#df_Angus_2013 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2013-07-01']
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013['Annual_Change'].max()
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013.reset_index()

df_Dumfries_Galloway_2014 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2014-07-01']
df_Dumfries_Galloway_Average_Price_2014 = df_Dumfries_Galloway_2014['Average_Price'].max()
#df_Aberdeenshire_2014 = df_Aberdeenshire_2014.reset_index()
print ('Dumfries and Galloway 2008-07 to 2014-07 price change:',
       (df_Dumfries_Galloway_Average_Price_2014-df_Dumfries_Galloway_Average_Price_200807)/
       df_Dumfries_Galloway_Average_Price_200907 * 100, '%')
print ('Dumfries and Galloway 2014-07 average price:', df_Dumfries_Galloway_Average_Price_2014)
print ('')

#df_Aberdeenshire_2015 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2015-07-01']
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015['Annual_Change'].max()
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015.reset_index()

df_Dumfries_Galloway_2016 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2016-07-01']
df_Dumfries_Galloway_Average_Price_2016 = df_Dumfries_Galloway_2016['Average_Price'].max()

print ('Dumfries and Galloway 2008-07 to 2016-07 price change:',
       (df_Dumfries_Galloway_Average_Price_2016-df_Dumfries_Galloway_Average_Price_200807)/
       df_Dumfries_Galloway_Average_Price_200907 * 100, '%')
print ('Dumfries and Galloway 2016-07 average price:', df_Dumfries_Galloway_Average_Price_2016)
print ('')

#df_Angus_2017 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2017-07-01']
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017['Annual_Change'].max()
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017.reset_index()

df_Dumfries_Galloway_2018 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2018-07-01']
df_Dumfries_Galloway_Average_Price_2018 = df_Dumfries_Galloway_2018['Average_Price'].max()

print ('Dumfries and Galloway 2008-07 to 2018-07 price change:',
       (df_Dumfries_Galloway_Average_Price_2018-df_Dumfries_Galloway_Average_Price_200807)/
       df_Dumfries_Galloway_Average_Price_200807 * 100, '%')
print ('Dumfries and Galloway 2018-07 average price:', df_Dumfries_Galloway_Average_Price_2018)
print ('')

df_Dumfries_Galloway_201907 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2019-07-01']
df_Dumfries_Galloway_Average_Price_201907 = df_Dumfries_Galloway_201907['Average_Price'].max()

print ('Dumfries and Galloway 2008-07 to 2019-07 price change:',
       (df_Dumfries_Galloway_Average_Price_201907-df_Dumfries_Galloway_Average_Price_200807)/
       df_Dumfries_Galloway_Average_Price_200807 * 100, '%')
print ('Dumfries and Galloway 2019-07 average price:', df_Dumfries_Galloway_Average_Price_201907)
#print ('')

df_Dumfries_Galloway_201912 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2019-12-01']
df_Dumfries_Galloway_Average_Price_201912 = df_Dumfries_Galloway_201912['Average_Price'].max()

print ('Dumfries and Galloway 2019-12 average price:', df_Dumfries_Galloway_Average_Price_201912)
print ('')

df_Dumfries_Galloway_202007 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2020-07-01']
df_Dumfries_Galloway_Average_Price_202007 = df_Dumfries_Galloway_202007['Average_Price'].max()

print ('Dumfries and Galloway 2019-07 to 2020-07 price change:',
       (df_Dumfries_Galloway_Average_Price_202007-df_Dumfries_Galloway_Average_Price_201907)/
       df_Dumfries_Galloway_Average_Price_201907 * 100, '%')
print ('Dumfries and Galloway 2020-07 average price:', df_Dumfries_Galloway_Average_Price_202007)
print ('')

#df_Aberdeenshire_202012 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2020-12-01']
#df_Aberdeenshire_Average_Price_202012 = df_Aberdeenshire_202012['Average_Price'].max()
#df_Aberdeenshire_2020 = df_Aberdeenshire_2020.reset_index()
#print ('Aberdeenshire 2020-07 to 2020-12 price change:',
#       (df_Aberdeenshire_Average_Price_202012-df_Aberdeenshire_Average_Price_202007)/
#       df_Aberdeenshire_Average_Price_202007 * 100, '%')
#print ('')

df_Dumfries_Galloway_2021 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2021-07-01']
df_Dumfries_Galloway_Average_Price_2021 = df_Dumfries_Galloway_2021['Average_Price'].max()

print ('Dumfries and Galloway 2019-07 to 2021-07 price change:',
       (df_Dumfries_Galloway_Average_Price_2021-df_Dumfries_Galloway_Average_Price_201907)/
       df_Dumfries_Galloway_Average_Price_201907 * 100, '%')
print ('Dumfries and Galloway 2021-07 average price:', df_Dumfries_Galloway_Average_Price_2021)
print ('')

df_Dumfries_Galloway_2022 = df_Dumfries_Galloway[df_Dumfries_Galloway['Date'] == '2022-07-01']
df_Dumfries_Galloway_Average_Price_2022 = df_Dumfries_Galloway_2022['Average_Price'].max()

print ('Dumfries and Galloway 2019-07 to 2022-07 price change:',
       (df_Dumfries_Galloway_Average_Price_2022-df_Dumfries_Galloway_Average_Price_201907)/
       df_Dumfries_Galloway_Average_Price_201907 * 100, '%')
print ('Dumfries and Galloway 2022-07 average price:', df_Dumfries_Galloway_Average_Price_2022)
print ('')

print ('Dumfries and Galloway 2008-07 to 2022-07 price change:',
       (df_Dumfries_Galloway_Average_Price_2022-df_Dumfries_Galloway_Average_Price_200807)/
       df_Dumfries_Galloway_Average_Price_200807 * 100, '%')
print ('')
# Out:
# Dumfries and Galloway 2005-07 to 2008-07 price change: 32.587979658000805 %
# Dumfries and Galloway 2008-07 average price: 140791.8845
#
# Dumfries and Galloway 2008-07 to 2009-07 price change: -12.625626372662119 %
# Dumfries and Galloway 2009-07 average price: 123016.0272
#
# Dumfries and Galloway 2009-12 average price: 130834.9815
# Dumfries and Galloway 2008-07 to 2010-07 price change: -7.441641851167906 %
# Dumfries and Galloway 2010-07 average price: 130314.6567
#
# Dumfries and Galloway 2008-07 to 2012-07 price change: -12.821322524452736 %
# Dumfries and Galloway 2012-07 average price: 122740.5029
#
# Dumfries and Galloway 2008-07 to 2014-07 price change: -17.343726086449315 %
# Dumfries and Galloway 2014-07 average price: 119456.3217
#
# Dumfries and Galloway 2008-07 to 2016-07 price change: -19.98993420590645 %
# Dumfries and Galloway 2016-07 average price: 116201.0616
#
# Dumfries and Galloway 2008-07 to 2018-07 price change: -12.275148785298052 %
# ...

# %%
##Urban


df_East_Dunbartonshire = df_Urban[(df_Urban.Region_Name=="East Dunbartonshire")]
df_East_Renfrewshire = df_Urban[(df_Urban.Region_Name=="East Renfrewshire")]

df_Falkirk = df_Urban[(df_Urban.Region_Name=="Falkirk")]
df_Glasgow = df_Urban[(df_Urban.Region_Name=="City of Glasgow")]
df_Inverclyde = df_Urban[(df_Urban.Region_Name=="Inverclyde")]
df_Midlothian = df_Urban[(df_Urban.Region_Name=="Midlothian")]
df_North_Ayrshire = df_Urban[(df_Urban.Region_Name=="North Ayrshire")]
df_North_Lanarkshire = df_Urban[(df_Urban.Region_Name=="North Lanarkshire")]
df_Renfrewshire = df_Urban[(df_Urban.Region_Name=="Renfrewshire")]
df_South_Lanarkshire = df_Urban[(df_Urban.Region_Name=="South Lanarkshire")]
df_West_Dunbartonshire = df_Urban[(df_Urban.Region_Name=="West Dunbartonshire")]
df_West_Lothian = df_Urban[(df_Urban.Region_Name=="West Lothian")]

# this is needed so the row numbers are still in sequence

df_East_Dunbartonshire.reset_index(drop=True)
df_East_Renfrewshire.reset_index(drop=True)

df_Falkirk.reset_index(drop=True)
df_Glasgow.reset_index(drop=True)
df_Inverclyde.reset_index(drop=True)
df_Midlothian.reset_index(drop=True)
df_North_Ayrshire.reset_index(drop=True)
df_North_Lanarkshire.reset_index(drop=True)
df_Renfrewshire.reset_index(drop=True)
df_South_Lanarkshire.reset_index(drop=True)
df_West_Dunbartonshire.reset_index(drop=True)
df_West_Lothian.reset_index(drop=True)
# Out:
#            Date   Region_Name  Area_Code  Average_Price  Monthly_Change  \
# 0    2004-01-01  West Lothian  S12000040    82818.74601             NaN
# 1    2004-02-01  West Lothian  S12000040    83981.90659        1.404465
# 2    2004-03-01  West Lothian  S12000040    83050.71328       -1.108802
# 3    2004-04-01  West Lothian  S12000040    85565.79645        3.028370
# 4    2004-05-01  West Lothian  S12000040    86832.48289        1.480365
# ..          ...           ...        ...            ...             ...
# 218  2022-03-01  West Lothian  S12000040   193289.46979       -1.527714
# 219  2022-04-01  West Lothian  S12000040   196058.42898        1.432545
# 220  2022-05-01  West Lothian  S12000040   200948.04116        2.493957
# 221  2022-06-01  West Lothian  S12000040   207347.90637        3.184836
# 222  2022-07-01  West Lothian  S12000040   207756.00330        0.196817
#
#      Annual_Change  Average_Price_SA
# 0              NaN               NaN
# ...

# %%
#Urban includs 15 regions: Aberdeen City ,Dundee City, East Dunbartonshire, 
#East Renfrewshire, City of Edinburgh, Falkirk, Glasgow City, Inverclyde, 
#Midlothian, North Ayrshire, North Lanarkshire, Renfrewshire, South Lanarkshire, 
#West Dunbartonshire, West Lothian

#Rural's 16 regions: Aberdeenshire, Angus, Argyll and Bute, Dumfries and Galloway,
#East Ayrshire, East Lothian, Fife, Highland, Moray, Na h-Eileanan Siar, 
#Orkney Islands, Perth and Kinross, Scottish Borders, Shetland Islands, 
#South Ayrshire, Stirling


#Urban1 :Aberdeen City

df_Aberdeen_City = df_Urban[(df_Urban.Region_Name=="City of Aberdeen")]
df_Aberdeen_City.reset_index(drop=True)

df_Aberdeen_City_2005 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2005-07-01']
df_Aberdeen_City_annual_change_2005 = df_Aberdeen_City_2005['Annual_Change'].max()
df_Aberdeen_City_Average_Price_2005 = df_Aberdeen_City_2005['Average_Price'].max()

df_Aberdeen_City_200807 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2008-07-01']
df_Aberdeen_City_annual_change_200807 = df_Aberdeen_City_200807['Annual_Change'].max()
df_Aberdeen_City_Average_Price_200807 = df_Aberdeen_City_200807['Average_Price'].max()

print ('Aberdeen City 2005-07 to 2008-07 price change:',
       (df_Aberdeen_City_Average_Price_200807-df_Aberdeen_City_Average_Price_2005)/
       df_Aberdeen_City_Average_Price_2005 * 100, '%')
print ('Aberdeen City 2008-07 average price:', df_Aberdeen_City_Average_Price_200807)
print ('')

df_Aberdeen_City_200907 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2009-07-01']
df_Aberdeen_City_annual_change_200907 = df_Aberdeen_City_200907['Annual_Change'].max()
df_Aberdeen_City_Average_Price_200907 = df_Aberdeen_City_200907['Average_Price'].max()

print ('Aberdeen City 2008-07 to 2009-07 price change:',
       (df_Aberdeen_City_Average_Price_200907-df_Aberdeen_City_Average_Price_200807)/
       df_Aberdeen_City_Average_Price_200807 * 100, '%')
print ('Aberdeen City 2009-07 average price:', df_Aberdeen_City_Average_Price_200907)
print ('')

df_Aberdeen_City_200912 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2009-12-01']
df_Aberdeen_City_annual_change_200912 = df_Aberdeen_City_200912['Annual_Change'].max()
df_Aberdeen_City_Average_Price_200912 = df_Aberdeen_City_200912['Average_Price'].max()

print ('Aberdeen City 2009-12 average price:', df_Aberdeen_City_Average_Price_200912)

df_Aberdeen_City_2010 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2010-07-01']
df_Aberdeen_City_Average_Price_2010 = df_Aberdeen_City_2010['Average_Price'].max()

print ('Aberdeen City 2008-07 to 2010-07 price change:',
       (df_Aberdeen_City_Average_Price_2010-df_Aberdeen_City_Average_Price_200807)/
       df_Aberdeen_City_Average_Price_200807 * 100, '%')
print ('Aberdeen City 2010-07 average price:', df_Aberdeen_City_Average_Price_2010)
print ('')

df_Aberdeen_City_2011 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2011-07-01']
df_Aberdeen_City_2011 = df_Aberdeen_City_2011['Annual_Change'].max()

df_Aberdeen_City_2012 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2012-07-01']
df_Aberdeen_City_Average_Price_2012 = df_Aberdeen_City_2012['Average_Price'].max()

print ('Aberdeen City 2008-07 to 2012-07 price change:',
       (df_Aberdeen_City_Average_Price_2012-df_Aberdeen_City_Average_Price_200807)/
       df_Aberdeen_City_Average_Price_200807 * 100, '%')
print ('Aberdeen City 2012-07 average price:', df_Aberdeen_City_Average_Price_2012)
print ('')

#df_Angus_2013 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2013-07-01']
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013['Annual_Change'].max()
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013.reset_index()

df_Aberdeen_City_2014 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2014-07-01']
df_Aberdeen_City_Average_Price_2014 = df_Aberdeen_City_2014['Average_Price'].max()
#df_Aberdeenshire_2014 = df_Aberdeenshire_2014.reset_index()
print ('Aberdeen City 2008-07 to 2014-07 price change:',
       (df_Aberdeen_City_Average_Price_2014-df_Aberdeen_City_Average_Price_200807)/
       df_Aberdeen_City_Average_Price_200907 * 100, '%')
print ('Aberdeen City 2014-07 average price:', df_Aberdeen_City_Average_Price_2014)
print ('')

#df_Aberdeenshire_2015 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2015-07-01']
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015['Annual_Change'].max()
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015.reset_index()

df_Aberdeen_City_2016 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2016-07-01']
df_Aberdeen_City_Average_Price_2016 = df_Aberdeen_City_2016['Average_Price'].max()

print ('Aberdeen City 2008-07 to 2016-07 price change:',
       (df_Aberdeen_City_Average_Price_2016-df_Aberdeen_City_Average_Price_200807)/
       df_Aberdeen_City_Average_Price_200907 * 100, '%')
print ('Aberdeen City 2016-07 average price:', df_Aberdeen_City_Average_Price_2016)
print ('')

#df_Angus_2017 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2017-07-01']
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017['Annual_Change'].max()
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017.reset_index()

df_Aberdeen_City_2018 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2018-07-01']
df_Aberdeen_City_Average_Price_2018 = df_Aberdeen_City_2018['Average_Price'].max()

print ('Aberdeen City 2008-07 to 2018-07 price change:',
       (df_Aberdeen_City_Average_Price_2018-df_Aberdeen_City_Average_Price_200807)/
       df_Aberdeen_City_Average_Price_200807 * 100, '%')
print ('Aberdeen City 2018-07 average price:', df_Aberdeen_City_Average_Price_2018)
print ('')

df_Aberdeen_City_201907 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2019-07-01']
df_Aberdeen_City_Average_Price_201907 = df_Aberdeen_City_201907['Average_Price'].max()

print ('Aberdeen City 2008-07 to 2019-07 price change:',
       (df_Aberdeen_City_Average_Price_201907-df_Aberdeen_City_Average_Price_200807)/
       df_Aberdeen_City_Average_Price_200807 * 100, '%')
print ('Aberdeen City 2019-07 average price:', df_Aberdeen_City_Average_Price_201907)
#print ('')

df_Aberdeen_City_201912 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2019-12-01']
df_Aberdeen_City_Average_Price_201912 = df_Aberdeen_City_201912['Average_Price'].max()

print ('Aberdeen City 2019-12 average price:', df_Aberdeen_City_Average_Price_201912)
print ('')

df_Aberdeen_City_202007 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2020-07-01']
df_Aberdeen_City_Average_Price_202007 = df_Aberdeen_City_202007['Average_Price'].max()

print ('Aberdeen City 2019-07 to 2020-07 price change:',
       (df_Aberdeen_City_Average_Price_202007-df_Aberdeen_City_Average_Price_201907)/
       df_Aberdeen_City_Average_Price_201907 * 100, '%')
print ('Aberdeen City 2020-07 average price:', df_Aberdeen_City_Average_Price_202007)
print ('')

#df_Aberdeenshire_202012 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2020-12-01']
#df_Aberdeenshire_Average_Price_202012 = df_Aberdeenshire_202012['Average_Price'].max()
#df_Aberdeenshire_2020 = df_Aberdeenshire_2020.reset_index()
#print ('Aberdeenshire 2020-07 to 2020-12 price change:',
#       (df_Aberdeenshire_Average_Price_202012-df_Aberdeenshire_Average_Price_202007)/
#       df_Aberdeenshire_Average_Price_202007 * 100, '%')
#print ('')

df_Aberdeen_City_2021 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2021-07-01']
df_Aberdeen_City_Average_Price_2021 = df_Aberdeen_City_2021['Average_Price'].max()

print ('Aberdeen City 2019-07 to 2021-07 price change:',
       (df_Aberdeen_City_Average_Price_2021-df_Aberdeen_City_Average_Price_201907)/
       df_Aberdeen_City_Average_Price_201907 * 100, '%')
print ('Aberdeen City 2021-07 average price:', df_Aberdeen_City_Average_Price_2021)
print ('')

df_Aberdeen_City_2022 = df_Aberdeen_City[df_Aberdeen_City['Date'] == '2022-07-01']
df_Aberdeen_City_Average_Price_2022 = df_Aberdeen_City_2022['Average_Price'].max()

print ('Aberdeen City 2019-07 to 2022-07 price change:',
       (df_Aberdeen_City_Average_Price_2022-df_Aberdeen_City_Average_Price_201907)/
       df_Aberdeen_City_Average_Price_201907 * 100, '%')
print ('Aberdeen City 2022-07 average price:', df_Aberdeen_City_Average_Price_2022)
print ('')

print ('Aberdeen City 2008-07 to 2022-07 price change:',
       (df_Aberdeen_City_Average_Price_2022-df_Aberdeen_City_Average_Price_200807)/
       df_Aberdeen_City_Average_Price_200807 * 100, '%')
print ('')
# Out:
# Aberdeen City 2005-07 to 2008-07 price change: 70.91161483159134 %
# Aberdeen City 2008-07 average price: 171219.6179
#
# Aberdeen City 2008-07 to 2009-07 price change: -7.338077758903822 %
# Aberdeen City 2009-07 average price: 158655.3892
#
# Aberdeen City 2009-12 average price: 158772.4093
# Aberdeen City 2008-07 to 2010-07 price change: -2.73738018895557 %
# Aberdeen City 2010-07 average price: 166532.686
#
# Aberdeen City 2008-07 to 2012-07 price change: -4.51520882642971 %
# Aberdeen City 2012-07 average price: 163488.6946
#
# Aberdeen City 2008-07 to 2014-07 price change: 16.356942257590816 %
# Aberdeen City 2014-07 average price: 197170.7883
#
# Aberdeen City 2008-07 to 2016-07 price change: 5.967541945937242 %
# Aberdeen City 2016-07 average price: 180687.4448
#
# Aberdeen City 2008-07 to 2018-07 price change: -7.609947539778969 %
# Aberdeen City 2018-07 average price: 158189.8948
#
# Aberdeen City 2008-07 to 2019-07 price change: -13.872690811559169 %
# ...

# %%
#Urban includs 15 regions: Aberdeen City ,Dundee City, East Dunbartonshire, 
#East Renfrewshire, City of Edinburgh, Falkirk, Glasgow City, Inverclyde, 
#Midlothian, North Ayrshire, North Lanarkshire, Renfrewshire, South Lanarkshire, 
#West Dunbartonshire, West Lothian

#Rural's 16 regions: Aberdeenshire, Angus, Argyll and Bute, Dumfries and Galloway,
#East Ayrshire, East Lothian, Fife, Highland, Moray, Na h-Eileanan Siar, 
#Orkney Islands, Perth and Kinross, Scottish Borders, Shetland Islands, 
#South Ayrshire, Stirling


#Urban2 :Dundee City

df_Dundee_City = df_Urban[(df_Urban.Region_Name=="City of Dundee")]
df_Dundee_City.reset_index(drop=True)

df_Dundee_City_2005 = df_Dundee_City[df_Dundee_City['Date'] == '2005-07-01']
df_Dundee_City_annual_change_2005 = df_Dundee_City_2005['Annual_Change'].max()
df_Dundee_City_Average_Price_2005 = df_Dundee_City_2005['Average_Price'].max()

df_Dundee_City_200807 = df_Dundee_City[df_Dundee_City['Date'] == '2008-07-01']
df_Dundee_City_annual_change_200807 = df_Dundee_City_200807['Annual_Change'].max()
df_Dundee_City_Average_Price_200807 = df_Dundee_City_200807['Average_Price'].max()

print ('Dundee City 2005-07 to 2008-07 price change:',
       (df_Dundee_City_Average_Price_200807-df_Dundee_City_Average_Price_2005)/
       df_Dundee_City_Average_Price_2005 * 100, '%')
print ('Dundee City 2008-07 average price:', df_Dundee_City_Average_Price_200807)
print ('')

df_Dundee_City_200907 = df_Dundee_City[df_Dundee_City['Date'] == '2009-07-01']
df_Dundee_City_annual_change_200907 = df_Dundee_City_200907['Annual_Change'].max()
df_Dundee_City_Average_Price_200907 = df_Dundee_City_200907['Average_Price'].max()

print ('Dundee City 2008-07 to 2009-07 price change:',
       (df_Dundee_City_Average_Price_200907-df_Dundee_City_Average_Price_200807)/
       df_Dundee_City_Average_Price_200807 * 100, '%')
print ('Dundee City 2009-07 average price:', df_Dundee_City_Average_Price_200907)
print ('')

df_Dundee_City_200912 = df_Dundee_City[df_Dundee_City['Date'] == '2009-12-01']
df_Dundee_City_annual_change_200912 = df_Dundee_City_200912['Annual_Change'].max()
df_Dundee_City_Average_Price_200912 = df_Dundee_City_200912['Average_Price'].max()

print ('Dundee City 2009-12 average price:', df_Aberdeen_City_Average_Price_200912)

df_Dundee_City_2010 = df_Dundee_City[df_Dundee_City['Date'] == '2010-07-01']
df_Dundee_City_Average_Price_2010 = df_Dundee_City_2010['Average_Price'].max()

print ('Dundee City 2008-07 to 2010-07 price change:',
       (df_Dundee_City_Average_Price_2010-df_Dundee_City_Average_Price_200807)/
       df_Dundee_City_Average_Price_200807 * 100, '%')
print ('Dundee City 2010-07 average price:', df_Dundee_City_Average_Price_2010)
print ('')

df_Dundee_City_2011 = df_Dundee_City[df_Dundee_City['Date'] == '2011-07-01']
df_Dundee_City_2011 = df_Dundee_City_2011['Annual_Change'].max()

df_Dundee_City_2012 = df_Dundee_City[df_Dundee_City['Date'] == '2012-07-01']
df_Dundee_City_Average_Price_2012 = df_Dundee_City_2012['Average_Price'].max()

print ('Dundee City 2008-07 to 2012-07 price change:',
       (df_Dundee_City_Average_Price_2012-df_Dundee_City_Average_Price_200807)/
       df_Dundee_City_Average_Price_200807 * 100, '%')
print ('Dundee City 2012-07 average price:', df_Dundee_City_Average_Price_2012)
print ('')

#df_Angus_2013 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2013-07-01']
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013['Annual_Change'].max()
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013.reset_index()

df_Dundee_City_2014 = df_Dundee_City[df_Dundee_City['Date'] == '2014-07-01']
df_Dundee_City_Average_Price_2014 = df_Dundee_City_2014['Average_Price'].max()
#df_Aberdeenshire_2014 = df_Aberdeenshire_2014.reset_index()
print ('Dundee City 2008-07 to 2014-07 price change:',
       (df_Dundee_City_Average_Price_2014-df_Dundee_City_Average_Price_200807)/
       df_Dundee_City_Average_Price_200907 * 100, '%')
print ('Dundee City 2014-07 average price:', df_Dundee_City_Average_Price_2014)
print ('')

#df_Aberdeenshire_2015 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2015-07-01']
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015['Annual_Change'].max()
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015.reset_index()

df_Dundee_City_2016 = df_Dundee_City[df_Dundee_City['Date'] == '2016-07-01']
df_Dundee_City_Average_Price_2016 = df_Dundee_City_2016['Average_Price'].max()

print ('Dundee City 2008-07 to 2016-07 price change:',
       (df_Dundee_City_Average_Price_2016-df_Dundee_City_Average_Price_200807)/
       df_Dundee_City_Average_Price_200907 * 100, '%')
print ('Dundee City 2016-07 average price:', df_Dundee_City_Average_Price_2016)
print ('')

#df_Angus_2017 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2017-07-01']
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017['Annual_Change'].max()
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017.reset_index()

df_Dundee_City_2018 = df_Dundee_City[df_Dundee_City['Date'] == '2018-07-01']
df_Dundee_City_Average_Price_2018 = df_Dundee_City_2018['Average_Price'].max()

print ('Dundee City 2008-07 to 2018-07 price change:',
       (df_Dundee_City_Average_Price_2018-df_Dundee_City_Average_Price_200807)/
       df_Dundee_City_Average_Price_200807 * 100, '%')
print ('Dundee City 2018-07 average price:', df_Aberdeen_City_Average_Price_2018)
print ('')

df_Dundee_City_201907 = df_Dundee_City[df_Dundee_City['Date'] == '2019-07-01']
df_Dundee_City_Average_Price_201907 = df_Dundee_City_201907['Average_Price'].max()

print ('Dundee City 2008-07 to 2019-07 price change:',
       (df_Dundee_City_Average_Price_201907-df_Dundee_City_Average_Price_200807)/
       df_Dundee_City_Average_Price_200807 * 100, '%')
print ('Dundee City 2019-07 average price:', df_Dundee_City_Average_Price_201907)
#print ('')

df_Dundee_City_201912 = df_Dundee_City[df_Dundee_City['Date'] == '2019-12-01']
df_Dundee_City_Average_Price_201912 = df_Dundee_City_201912['Average_Price'].max()

print ('Dundee City 2019-12 average price:', df_Dundee_City_Average_Price_201912)
print ('')

df_Dundee_City_202007 = df_Dundee_City[df_Dundee_City['Date'] == '2020-07-01']
df_Dundee_City_Average_Price_202007 = df_Dundee_City_202007['Average_Price'].max()

print ('Dundee City 2019-07 to 2020-07 price change:',
       (df_Dundee_City_Average_Price_202007-df_Dundee_City_Average_Price_201907)/
       df_Dundee_City_Average_Price_201907 * 100, '%')
print ('Dundee City 2020-07 average price:', df_Dundee_City_Average_Price_202007)
print ('')

#df_Aberdeenshire_202012 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2020-12-01']
#df_Aberdeenshire_Average_Price_202012 = df_Aberdeenshire_202012['Average_Price'].max()
#df_Aberdeenshire_2020 = df_Aberdeenshire_2020.reset_index()
#print ('Aberdeenshire 2020-07 to 2020-12 price change:',
#       (df_Aberdeenshire_Average_Price_202012-df_Aberdeenshire_Average_Price_202007)/
#       df_Aberdeenshire_Average_Price_202007 * 100, '%')
#print ('')

df_Dundee_City_2021 = df_Dundee_City[df_Dundee_City['Date'] == '2021-07-01']
df_Dundee_City_Average_Price_2021 = df_Dundee_City_2021['Average_Price'].max()

print ('Dundee City 2019-07 to 2021-07 price change:',
       (df_Dundee_City_Average_Price_2021-df_Dundee_City_Average_Price_201907)/
       df_Dundee_City_Average_Price_201907 * 100, '%')
print ('Dundee City 2021-07 average price:', df_Dundee_City_Average_Price_2021)
print ('')

df_Dundee_City_2022 = df_Dundee_City[df_Dundee_City['Date'] == '2022-07-01']
df_Dundee_City_Average_Price_2022 = df_Dundee_City_2022['Average_Price'].max()

print ('Dundee City 2019-07 to 2022-07 price change:',
       (df_Dundee_City_Average_Price_2022-df_Dundee_City_Average_Price_201907)/
       df_Dundee_City_Average_Price_201907 * 100, '%')
print ('Dundee City 2022-07 average price:', df_Dundee_City_Average_Price_2022)
print ('')

print ('Dundee City 2008-07 to 2022-07 price change:',
       (df_Dundee_City_Average_Price_2022-df_Dundee_City_Average_Price_200807)/
       df_Dundee_City_Average_Price_200807 * 100, '%')
print ('')
# Out:
# Dundee City 2005-07 to 2008-07 price change: 31.782061094349668 %
# Dundee City 2008-07 average price: 117409.0672
#
# Dundee City 2008-07 to 2009-07 price change: -6.474191458357831 %
# Dundee City 2009-07 average price: 109807.7794
#
# Dundee City 2009-12 average price: 158772.4093
# Dundee City 2008-07 to 2010-07 price change: -3.471274576313136 %
# Dundee City 2010-07 average price: 113333.4761
#
# Dundee City 2008-07 to 2012-07 price change: -6.60391815122095 %
# Dundee City 2012-07 average price: 109655.4685
#
# Dundee City 2008-07 to 2014-07 price change: 0.04880246216871217 %
# Dundee City 2014-07 average price: 117462.6561
#
# Dundee City 2008-07 to 2016-07 price change: 1.4653304244853862 %
# Dundee City 2016-07 average price: 119018.114
#
# Dundee City 2008-07 to 2018-07 price change: 6.677308990663711 %
# Dundee City 2018-07 average price: 158189.8948
#
# Dundee City 2008-07 to 2019-07 price change: 8.8666124757356 %
# Dundee City 2019-07 average price: 127819.2742
# ...

# %%
#Urban includs 15 regions: Aberdeen City ,Dundee City, East Dunbartonshire, 
#East Renfrewshire, City of Edinburgh, Falkirk, Glasgow City, Inverclyde, 
#Midlothian, North Ayrshire, North Lanarkshire, Renfrewshire, South Lanarkshire, 
#West Dunbartonshire, West Lothian

#Rural's 16 regions: Aberdeenshire, Angus, Argyll and Bute, Dumfries and Galloway,
#East Ayrshire, East Lothian, Fife, Highland, Moray, Na h-Eileanan Siar, 
#Orkney Islands, Perth and Kinross, Scottish Borders, Shetland Islands, 
#South Ayrshire, Stirling


#Urban5 :City of Edinburgh

df_Edinburgh = df_Urban[(df_Urban.Region_Name=="City of Edinburgh")]
df_Edinburgh.reset_index(drop=True)

df_Edinburgh_2005 = df_Edinburgh[df_Edinburgh['Date'] == '2005-07-01']
df_Edinburgh_annual_change_2005 = df_Edinburgh_2005['Annual_Change'].max()
df_Edinburgh_Average_Price_2005 = df_Edinburgh_2005['Average_Price'].max()

df_Edinburgh_200807 = df_Edinburgh[df_Edinburgh['Date'] == '2008-07-01']
df_Edinburgh_annual_change_200807 = df_Edinburgh_200807['Annual_Change'].max()
df_Edinburgh_Average_Price_200807 = df_Edinburgh_200807['Average_Price'].max()

print ('Edinburgh 2005-07 to 2008-07 price change:',
       (df_Edinburgh_Average_Price_200807-df_Edinburgh_Average_Price_2005)/
       df_Edinburgh_Average_Price_2005 * 100, '%')
print ('Edinburgh 2008-07 average price:', df_Edinburgh_Average_Price_200807)
print ('')

df_Edinburgh_200907 = df_Edinburgh[df_Edinburgh['Date'] == '2009-07-01']
df_Edinburgh_annual_change_200907 = df_Edinburgh_200907['Annual_Change'].max()
df_Edinburgh_Average_Price_200907 = df_Edinburgh_200907['Average_Price'].max()

print ('Edinburgh 2008-07 to 2009-07 price change:',
       (df_Edinburgh_Average_Price_200907-df_Edinburgh_Average_Price_200807)/
       df_Edinburgh_Average_Price_200807 * 100, '%')
print ('Edinburgh 2009-07 average price:', df_Edinburgh_Average_Price_200907)
print ('')

df_Edinburgh_200912 = df_Edinburgh[df_Edinburgh['Date'] == '2009-12-01']
df_Edinburgh_annual_change_200912 = df_Edinburgh_200912['Annual_Change'].max()
df_Edinburgh_Average_Price_200912 = df_Edinburgh_200912['Average_Price'].max()

print ('Edinburgh 2009-12 average price:', df_Edinburgh_Average_Price_200912)

df_Edinburgh_2010 = df_Edinburgh[df_Edinburgh['Date'] == '2010-07-01']
df_Edinburgh_Average_Price_2010 = df_Edinburgh_2010['Average_Price'].max()

print ('Edinburgh 2008-07 to 2010-07 price change:',
       (df_Edinburgh_Average_Price_2010-df_Edinburgh_Average_Price_200807)/
       df_Edinburgh_Average_Price_200807 * 100, '%')
print ('Edinburgh 2010-07 average price:', df_Edinburgh_Average_Price_2010)
print ('')

df_Edinburgh_2011 = df_Edinburgh[df_Edinburgh['Date'] == '2011-07-01']
df_Edinburgh_2011 = df_Edinburgh_2011['Annual_Change'].max()

df_Edinburgh_2012 = df_Edinburgh[df_Edinburgh['Date'] == '2012-07-01']
df_Edinburgh_Average_Price_2012 = df_Edinburgh_2012['Average_Price'].max()

print ('Edinburgh 2008-07 to 2012-07 price change:',
       (df_Edinburgh_Average_Price_2012-df_Edinburgh_Average_Price_200807)/
       df_Edinburgh_Average_Price_200807 * 100, '%')
print ('Edinburgh 2012-07 average price:', df_Edinburgh_Average_Price_2012)
print ('')

#df_Angus_2013 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2013-07-01']
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013['Annual_Change'].max()
#df_Aberdeenshire_2013 = df_Aberdeenshire_2013.reset_index()

df_Edinburgh_2014 = df_Edinburgh[df_Edinburgh['Date'] == '2014-07-01']
df_Edinburgh_Average_Price_2014 = df_Edinburgh_2014['Average_Price'].max()
#df_Aberdeenshire_2014 = df_Aberdeenshire_2014.reset_index()
print ('Edinburgh 2008-07 to 2014-07 price change:',
       (df_Edinburgh_Average_Price_2014-df_Edinburgh_Average_Price_200807)/
       df_Edinburgh_Average_Price_200907 * 100, '%')
print ('Edinburgh 2014-07 average price:', df_Edinburgh_Average_Price_2014)
print ('')

#df_Aberdeenshire_2015 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2015-07-01']
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015['Annual_Change'].max()
#df_Aberdeenshire_2015 = df_Aberdeenshire_2015.reset_index()

df_Edinburgh_2016 = df_Edinburgh[df_Edinburgh['Date'] == '2016-07-01']
df_Edinburgh_Average_Price_2016 = df_Edinburgh_2016['Average_Price'].max()

print ('Edinburgh 2008-07 to 2016-07 price change:',
       (df_Edinburgh_Average_Price_2016-df_Edinburgh_Average_Price_200807)/
       df_Edinburgh_Average_Price_200907 * 100, '%')
print ('Edinburgh 2016-07 average price:', df_Edinburgh_Average_Price_2016)
print ('')

#df_Angus_2017 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2017-07-01']
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017['Annual_Change'].max()
#df_Aberdeenshire_2017 = df_Aberdeenshire_2017.reset_index()

df_Edinburgh_2018 = df_Edinburgh[df_Edinburgh['Date'] == '2018-07-01']
df_Edinburgh_Average_Price_2018 = df_Edinburgh_2018['Average_Price'].max()

print ('Edinburgh 2008-07 to 2018-07 price change:',
       (df_Edinburgh_Average_Price_2018-df_Edinburgh_Average_Price_200807)/
       df_Edinburgh_Average_Price_200807 * 100, '%')
print ('Edinburgh 2018-07 average price:', df_Edinburgh_Average_Price_2018)
print ('')

df_Edinburgh_201907 = df_Edinburgh[df_Edinburgh['Date'] == '2019-07-01']
df_Edinburgh_Average_Price_201907 = df_Edinburgh_201907['Average_Price'].max()

print ('Edinburgh 2008-07 to 2019-07 price change:',
       (df_Edinburgh_Average_Price_201907-df_Edinburgh_Average_Price_200807)/
       df_Edinburgh_Average_Price_200807 * 100, '%')
print ('Edinburgh 2019-07 average price:', df_Edinburgh_Average_Price_201907)
#print ('')

df_Edinburgh_201912 = df_Edinburgh[df_Edinburgh['Date'] == '2019-12-01']
df_Edinburgh_Average_Price_201912 = df_Edinburgh_201912['Average_Price'].max()

print ('Edinburgh 2019-12 average price:', df_Edinburgh_Average_Price_201912)
print ('')

df_Edinburgh_202007 = df_Edinburgh[df_Edinburgh['Date'] == '2020-07-01']
df_Edinburgh_Average_Price_202007 = df_Edinburgh_202007['Average_Price'].max()

print ('Edinburgh 2019-07 to 2020-07 price change:',
       (df_Edinburgh_Average_Price_202007-df_Edinburgh_Average_Price_201907)/
       df_Edinburgh_Average_Price_201907 * 100, '%')
print ('Edinburgh 2020-07 average price:', df_Edinburgh_Average_Price_202007)
print ('')

#df_Aberdeenshire_202012 = df_Aberdeenshire[df_Aberdeenshire['Date'] == '2020-12-01']
#df_Aberdeenshire_Average_Price_202012 = df_Aberdeenshire_202012['Average_Price'].max()
#df_Aberdeenshire_2020 = df_Aberdeenshire_2020.reset_index()
#print ('Aberdeenshire 2020-07 to 2020-12 price change:',
#       (df_Aberdeenshire_Average_Price_202012-df_Aberdeenshire_Average_Price_202007)/
#       df_Aberdeenshire_Average_Price_202007 * 100, '%')
#print ('')

df_Edinburgh_2021 = df_Edinburgh[df_Edinburgh['Date'] == '2021-07-01']
df_Edinburgh_Average_Price_2021 = df_Edinburgh_2021['Average_Price'].max()

print ('Edinburgh 2019-07 to 2021-07 price change:',
       (df_Edinburgh_Average_Price_2021-df_Edinburgh_Average_Price_201907)/
       df_Edinburgh_Average_Price_201907 * 100, '%')
print ('Edinburgh 2021-07 average price:', df_Edinburgh_Average_Price_2021)
print ('')

df_Edinburgh_2022 = df_Edinburgh[df_Edinburgh['Date'] == '2022-07-01']
df_Edinburgh_Average_Price_2022 = df_Edinburgh_2022['Average_Price'].max()

print ('Edinburgh 2019-07 to 2022-07 price change:',
       (df_Edinburgh_Average_Price_2022-df_Edinburgh_Average_Price_201907)/
       df_Edinburgh_Average_Price_201907 * 100, '%')
print ('Edinburgh 2022-07 average price:', df_Edinburgh_Average_Price_2022)
print ('')

print ('Edinburgh 2008-07 to 2022-07 price change:',
       (df_Edinburgh_Average_Price_2022-df_Edinburgh_Average_Price_200807)/
       df_Edinburgh_Average_Price_200807 * 100, '%')
print ('')
# Out:
# Edinburgh 2005-07 to 2008-07 price change: 29.62355442535048 %
# Edinburgh 2008-07 average price: 222149.0866
#
# Edinburgh 2008-07 to 2009-07 price change: -8.202021164646103 %
# Edinburgh 2009-07 average price: 203928.3715
#
# Edinburgh 2009-12 average price: 213496.0726
# Edinburgh 2008-07 to 2010-07 price change: -3.1905052631443045 %
# Edinburgh 2010-07 average price: 215061.4083
#
# Edinburgh 2008-07 to 2012-07 price change: -6.63141587726879 %
# Edinburgh 2012-07 average price: 207417.4568
#
# Edinburgh 2008-07 to 2014-07 price change: -0.3147321264221508 %
# Edinburgh 2014-07 average price: 221507.2585
#
# Edinburgh 2008-07 to 2016-07 price change: 0.1749004306642058 %
# Edinburgh 2016-07 average price: 222505.7582
#
# Edinburgh 2008-07 to 2018-07 price change: 15.23736654427459 %
# Edinburgh 2018-07 average price: 255998.7572
#
# Edinburgh 2008-07 to 2019-07 price change: 20.764364736307684 %
# Edinburgh 2019-07 average price: 268276.9332
# ...
